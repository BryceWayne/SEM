# %%
import pickle
import numpy as np
import pandas as pd
from net.network import NetA, ResNet

# %%
def load_obj():
    with open('./losses.pkl', 'rb') as f:
        data = pickle.load(f)
    return data

data = load_obj()
for k, v in data.items():
    if data[k]['MODEL'] == NetA:
        data[k]['MODEL'] = 'NetA'
    elif data[k]['MODEL'] == ResNet:
        data[k]['MODEL'] = 'ResNet'

df = pd.DataFrame.from_dict(data, orient='index')
df
# Out:
#                                                                                        losses  \
# Standard\500N31\20200704T115102             {'loss_a': [0.0014008926153182984, 0.001366454...
# Standard\500N31\20200704T120619             {'loss_a': [0.0010492830276489257, 0.001015375...
# Standard\10000N31\20200704T121209           {'loss_a': [5.839865803718567e-05, 5.647708177...
# Standard\10000N31\20200704T124332           {'loss_a': [8.24008125, 7.69129140625, 0.36565...
# Burgers\10000N31\20200704T151344            {'loss_a': [4.11263984375, 3.829959375, 0.4715...
# ...                                                                                       ...
# training\Helmholtz\1000N63\20200706T220517  {'loss_a': [16.7665390625, 16.2884111328125, 1...
# training\Helmholtz\1000N63\20200706T222153  {'loss_a': [13.726263671875, 13.4100390625, 11...
# training\Helmholtz\1000N63\20200706T232852  {'loss_a': [10.73527734375, 10.4877822265625, ...
# training\Helmholtz\1000N63\20200707T115510  {'loss_a': [14.74994140625, 13.9466953125, 5.8...
# training\Helmholtz\2000N63\20200707T144332  {'loss_a': [0.0003385535180568695, 0.000328478...
#
#                                              EQUATION   MODEL  KERNEL_SIZE  \
# Standard\500N31\20200704T115102              Standard  ResNet            5
# Standard\500N31\20200704T120619              Standard  ResNet            5
# Standard\10000N31\20200704T121209            Standard  ResNet            5
# Standard\10000N31\20200704T124332            Standard  ResNet            5
# Burgers\10000N31\20200704T151344              Burgers  ResNet            5
# ...                                               ...     ...          ...
# training\Helmholtz\1000N63\20200706T220517  Helmholtz    NetA            5
# training\Helmholtz\1000N63\20200706T222153  Helmholtz    NetA            5
# training\Helmholtz\1000N63\20200706T232852  Helmholtz    NetA            5
# training\Helmholtz\1000N63\20200707T115510  Helmholtz    NetA            5
# training\Helmholtz\2000N63\20200707T144332  Helmholtz    NetA            5
#
#                                             BLOCKS  EPSILON LOSS_TYPE  \
# Standard\500N31\20200704T115102                  0      0.1       MAE
# Standard\500N31\20200704T120619                  0      0.1       MAE
# Standard\10000N31\20200704T121209                0      0.1       MAE
# Standard\10000N31\20200704T124332                0      0.1       MSE
# Burgers\10000N31\20200704T151344                 0      0.5       MSE
# ...                                            ...      ...       ...
# training\Helmholtz\1000N63\20200706T220517       2      0.0       MSE
# training\Helmholtz\1000N63\20200706T222153       2      0.0       MSE
# training\Helmholtz\1000N63\20200706T232852       2      0.0       MSE
# training\Helmholtz\1000N63\20200707T115510       2      0.0       MSE
# training\Helmholtz\2000N63\20200707T144332       3      0.0       MAE
#
#                                             FILTERS      MAEa      MSEa  \
# Standard\500N31\20200704T115102                 NaN       NaN       NaN
# Standard\500N31\20200704T120619                 NaN       NaN       NaN
# Standard\10000N31\20200704T121209               NaN       NaN       NaN
# Standard\10000N31\20200704T124332               NaN       NaN       NaN
# Burgers\10000N31\20200704T151344                NaN       NaN       NaN
# ...                                             ...       ...       ...
# training\Helmholtz\1000N63\20200706T220517      NaN       NaN       NaN
# training\Helmholtz\1000N63\20200706T222153      NaN       NaN       NaN
# training\Helmholtz\1000N63\20200706T232852      NaN       NaN       NaN
# training\Helmholtz\1000N63\20200707T115510      NaN       NaN       NaN
# training\Helmholtz\2000N63\20200707T144332     32.0  0.226399  9.168335
#
#                                                 MIEa      MAEu      MSEu  \
# Standard\500N31\20200704T115102                  NaN       NaN       NaN
# Standard\500N31\20200704T120619                  NaN       NaN       NaN
# Standard\10000N31\20200704T121209                NaN       NaN       NaN
# Standard\10000N31\20200704T124332                NaN       NaN       NaN
# Burgers\10000N31\20200704T151344                 NaN       NaN       NaN
# ...                                              ...       ...       ...
# training\Helmholtz\1000N63\20200706T220517       NaN       NaN       NaN
# training\Helmholtz\1000N63\20200706T222153       NaN       NaN       NaN
# training\Helmholtz\1000N63\20200706T232852       NaN       NaN       NaN
# training\Helmholtz\1000N63\20200707T115510       NaN       NaN       NaN
# training\Helmholtz\2000N63\20200707T144332  3.612519  0.397908  3.449737
#
#                                                 MIEu
# Standard\500N31\20200704T115102                  NaN
# Standard\500N31\20200704T120619                  NaN
# Standard\10000N31\20200704T121209                NaN
# Standard\10000N31\20200704T124332                NaN
# Burgers\10000N31\20200704T151344                 NaN
# ...                                              ...
# training\Helmholtz\1000N63\20200706T220517       NaN
# training\Helmholtz\1000N63\20200706T222153       NaN
# training\Helmholtz\1000N63\20200706T232852       NaN
# training\Helmholtz\1000N63\20200707T115510       NaN
# training\Helmholtz\2000N63\20200707T144332  5.161402
#
# [62 rows x 14 columns]

# %%
df['EQUATION'].unique()
# Out:
# array(['Standard', 'Burgers', 'Helmholtz'], dtype=object)
